# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Création d'une série temporelle avec des dates
dates = pd.date_range('2023-01-01', periods=365)
print(type( dates) )
ts = pd.Series(range(365), index=dates)
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
ts.head(10)
# Out:
# 2023-01-01    0
# 2023-01-02    1
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# 2023-01-06    5
# 2023-01-07    6
# 2023-01-08    7
# 2023-01-09    8
# 2023-01-10    9
# Freq: D, dtype: int64

# %%
ts['2023-01-01']
# Out:
# 0

# %%
ts.rolling(window=30).mean()
# Out:
# 2023-01-01      NaN
# 2023-01-02      NaN
# 2023-01-03      NaN
# 2023-01-04      NaN
# 2023-01-05      NaN
#               ...
# 2023-12-27    345.5
# 2023-12-28    346.5
# 2023-12-29    347.5
# 2023-12-30    348.5
# 2023-12-31    349.5
# Freq: D, Length: 365, dtype: float64

# %%
ts = ts.asfreq('D') 

ts.head()
# Out:
# 2023-01-01    0
# 2023-01-02    1
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# Freq: D, dtype: int64

# %%
ts.resample('ME').mean()
# Out:
# 2023-01-31     15.0
# 2023-02-28     44.5
# 2023-03-31     74.0
# 2023-04-30    104.5
# 2023-05-31    135.0
# 2023-06-30    165.5
# 2023-07-31    196.0
# 2023-08-31    227.0
# 2023-09-30    257.5
# 2023-10-31    288.0
# 2023-11-30    318.5
# 2023-12-31    349.0
# Freq: ME, dtype: float64

# %%
ts.groupby(pd.Grouper(freq='W')).sum()
# Out:
# 2023-01-01       0
# 2023-01-08      28
# 2023-01-15      77
# 2023-01-22     126
# 2023-01-29     175
# 2023-02-05     224
# 2023-02-12     273
# 2023-02-19     322
# 2023-02-26     371
# 2023-03-05     420
# 2023-03-12     469
# 2023-03-19     518
# 2023-03-26     567
# 2023-04-02     616
# 2023-04-09     665
# 2023-04-16     714
# 2023-04-23     763
# 2023-04-30     812
# 2023-05-07     861
# 2023-05-14     910
# 2023-05-21     959
# 2023-05-28    1008
# 2023-06-04    1057
# 2023-06-11    1106
# 2023-06-18    1155
# 2023-06-25    1204
# 2023-07-02    1253
# 2023-07-09    1302
# 2023-07-16    1351
# 2023-07-23    1400
# 2023-07-30    1449
# 2023-08-06    1498
# 2023-08-13    1547
# 2023-08-20    1596
# 2023-08-27    1645
# 2023-09-03    1694
# 2023-09-10    1743
# 2023-09-17    1792
# 2023-09-24    1841
# 2023-10-01    1890
# 2023-10-08    1939
# 2023-10-15    1988
# 2023-10-22    2037
# 2023-10-29    2086
# 2023-11-05    2135
# 2023-11-12    2184
# 2023-11-19    2233
# ...

# %%
import pandas as pd
import numpy as np

# Création d'une série temporelle fictive
np.random.seed(42) # garanti d'avoir le même jeu de données 
date_rng = pd.date_range(start='1/1/2020', end='31/12/2022', freq='ME')
sales = np.random.randint(20, 35, size=(len(date_rng))) + 10*np.sin(np.linspace(0, 3 * np.pi, len(date_rng)))

ts = pd.Series(sales, index=date_rng)

# %%
ts.head()
# Out:
# 2020-01-31    26.000000
# 2020-02-29    25.660368
# 2020-03-31    37.128993
# 2020-04-30    41.227949
# 2020-05-31    38.805955
# Freq: ME, dtype: float64

# %%
np.linspace(0, 3 * np.pi, len(date_rng) )
# Out:
# array([0.        , 0.26927937, 0.53855874, 0.80783811, 1.07711748,
#        1.34639685, 1.61567622, 1.88495559, 2.15423496, 2.42351433,
#        2.6927937 , 2.96207307, 3.23135244, 3.50063181, 3.76991118,
#        4.03919055, 4.30846992, 4.5777493 , 4.84702867, 5.11630804,
#        5.38558741, 5.65486678, 5.92414615, 6.19342552, 6.46270489,
#        6.73198426, 7.00126363, 7.270543  , 7.53982237, 7.80910174,
#        8.07838111, 8.34766048, 8.61693985, 8.88621922, 9.15549859,
#        9.42477796])

# %%
10*np.sin(np.linspace(0, 3 * np.pi, len(date_rng)) )
# Out:
# array([ 0.00000000e+00,  2.66036846e+00,  5.12899277e+00,  7.22794864e+00,
#         8.80595532e+00,  9.74927912e+00,  9.98993067e+00,  9.51056516e+00,
#         8.34573254e+00,  6.57938726e+00,  4.33883739e+00,  1.78556895e+00,
#        -8.96393089e-01, -3.51374824e+00, -5.87785252e+00, -7.81831482e+00,
#        -9.19527773e+00, -9.90949762e+00, -9.90949762e+00, -9.19527773e+00,
#        -7.81831482e+00, -5.87785252e+00, -3.51374824e+00, -8.96393089e-01,
#         1.78556895e+00,  4.33883739e+00,  6.57938726e+00,  8.34573254e+00,
#         9.51056516e+00,  9.98993067e+00,  9.74927912e+00,  8.80595532e+00,
#         7.22794864e+00,  5.12899277e+00,  2.66036846e+00,  3.67394040e-15])

# %%
np.random.randint(20, 35, size=(len(date_rng)))
# Out:
# array([22, 22, 20, 30, 24, 29, 26, 29, 28, 31, 26, 28, 27, 31, 21, 20, 26,
#        26, 33, 27, 24, 22, 31, 27, 25, 30, 22, 20, 22, 24, 34, 33, 22, 20,
#        24, 29])

# %%
len( date_rng )
# Out:
# 36

# %%
len( np.random.randint(20, 35, size=(len(date_rng)))  )
# Out:
# 36

# %%
 10*np.sin(np.linspace(0, 3 * np.pi, len(date_rng)))
# Out:
# array([ 0.00000000e+00,  2.66036846e+00,  5.12899277e+00,  7.22794864e+00,
#         8.80595532e+00,  9.74927912e+00,  9.98993067e+00,  9.51056516e+00,
#         8.34573254e+00,  6.57938726e+00,  4.33883739e+00,  1.78556895e+00,
#        -8.96393089e-01, -3.51374824e+00, -5.87785252e+00, -7.81831482e+00,
#        -9.19527773e+00, -9.90949762e+00, -9.90949762e+00, -9.19527773e+00,
#        -7.81831482e+00, -5.87785252e+00, -3.51374824e+00, -8.96393089e-01,
#         1.78556895e+00,  4.33883739e+00,  6.57938726e+00,  8.34573254e+00,
#         9.51056516e+00,  9.98993067e+00,  9.74927912e+00,  8.80595532e+00,
#         7.22794864e+00,  5.12899277e+00,  2.66036846e+00,  3.67394040e-15])

# %%
y = np.random.randint(20, 35, size=(len(date_rng)))  +  10*np.sin(np.linspace(0, 3 * np.pi, len(date_rng)))

# %%
np.sin(np.linspace(0, 3 * np.pi, len(date_rng)) )
# Out:
# array([ 0.00000000e+00,  2.66036846e-01,  5.12899277e-01,  7.22794864e-01,
#         8.80595532e-01,  9.74927912e-01,  9.98993067e-01,  9.51056516e-01,
#         8.34573254e-01,  6.57938726e-01,  4.33883739e-01,  1.78556895e-01,
#        -8.96393089e-02, -3.51374824e-01, -5.87785252e-01, -7.81831482e-01,
#        -9.19527773e-01, -9.90949762e-01, -9.90949762e-01, -9.19527773e-01,
#        -7.81831482e-01, -5.87785252e-01, -3.51374824e-01, -8.96393089e-02,
#         1.78556895e-01,  4.33883739e-01,  6.57938726e-01,  8.34573254e-01,
#         9.51056516e-01,  9.98993067e-01,  9.74927912e-01,  8.80595532e-01,
#         7.22794864e-01,  5.12899277e-01,  2.66036846e-01,  3.67394040e-16])

# %%
df = pd.DataFrame( { 'X' : range(36) , 'Y' : y } ) 

df.head()
# Out:
#    X          Y
# 0  0  32.000000
# 1  1  35.660368
# 2  2  33.128993
# 3  3  31.227949
# 4  4  33.805955

# %%
sns.lineplot(x="X", y="Y", data=df)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Décomposition de la série temporelle
decomposition = seasonal_decompose(ts, model='additive')

# Extraction des composants
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Affichage des composants
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(ts, label='Original')
plt.legend(loc='upper left')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='upper left')

plt.subplot(413)
plt.plot(seasonal, label='Seasonal')
plt.legend(loc='upper left')

plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
